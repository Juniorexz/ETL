# %%
import pandas as pd 
import pandera as pa

# %%
dataframe = pd.read_csv("ocorrencia20102020copia - Copia EDITADA.csv" , sep="\t",parse_dates=['ocorrencia_dia'])
dataframe
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-03-01
# 1                  BEL�M            PA                 SBBE     2010-03-01
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-04-01
# 4                PELOTAS            RS                 SBPK     2010-05-01
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     2020-12-29
# 5748   LAGOA DA CONFUS�O            TO                 ****     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 ****     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes  Unnamed: 9  Unnamed: 10
# 0           12:00:00                    0         NaN          NaN
# 1           11:05:00                    0         NaN          NaN
# 2           03:00:00                    0         NaN          NaN
# 3           17:30:00                    0         NaN          NaN
# 4           19:25:00                    0         NaN          NaN
# ...              ...                  ...         ...          ...
# 5747        19:00:00                    0         NaN          NaN
# 5748        18:30:00                    0         NaN          NaN
# 5749        00:54:00                    0         NaN          NaN
# 5750        09:00:00                    0         NaN          NaN
# 5751        13:24:00                    0         NaN          NaN
#
# [5752 rows x 11 columns]

# %%
dataframe.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# Unnamed: 9                         float64
# Unnamed: 10                        float64
# dtype: object

# %%
dataframe.ocorrencia_dia
# Out:
# 0      2010-03-01
# 1      2010-03-01
# 2      2010-03-01
# 3      2010-04-01
# 4      2010-05-01
#           ...
# 5747   2020-12-29
# 5748   2020-12-30
# 5749   2020-12-30
# 5750   2020-12-31
# 5751   2020-12-31
# Name: ocorrencia_dia, Length: 5752, dtype: datetime64[ns]

# %%
dataframe.ocorrencia_dia.dt.month
# Out:
# 0        3
# 1        3
# 2        3
# 3        4
# 4        5
#         ..
# 5747    12
# 5748    12
# 5749    12
# 5750    12
# 5751    12
# Name: ocorrencia_dia, Length: 5752, dtype: int64

# %%
datafdataframe = pd.read_csv("ocorrencia20102020copia - Copia EDITADA.csv" , sep="\t",parse_dates=['ocorrencia_dia'], dayfirst=True)
datafdataframe.tail(10)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5742              79800               79800                INCIDENTE
# 5743              79824               79824                 ACIDENTE
# 5744              79753               79753          INCIDENTE GRAVE
# 5745              79755               79755                 ACIDENTE
# 5746              79769               79769          INCIDENTE GRAVE
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5742          S�O PAULO            SP                 SBMT     2020-12-28
# 5743      RIO PARANA�BA            MG                 SNRP     2020-12-28
# 5744           GOIATUBA            GO                 ****     2020-12-29
# 5745          MATO RICO            PR                 ****     2020-12-29
# 5746      MANOEL URBANO            AC                 SIMB     2020-12-29
# 5747           CAMPINAS            SP                 SBKP     2020-12-29
# 5748  LAGOA DA CONFUS�O            TO                 ****     2020-12-30
# 5749     RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750          VICENTINA            MS                 ****     2020-12-31
# 5751     RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes  Unnamed: 9  Unnamed: 10
# 5742        10:15:00                    0         NaN          NaN
# 5743        17:00:00                    0         NaN          NaN
# 5744        12:00:00                    0         NaN          NaN
# 5745        10:30:00                    0         NaN          NaN
# 5746        18:30:00                    0         NaN          NaN
# 5747        19:00:00                    0         NaN          NaN
# 5748        18:30:00                    0         NaN          NaN
# 5749        00:54:00                    0         NaN          NaN
# 5750        09:00:00                    0         NaN          NaN
# 5751        13:24:00                    0         NaN          NaN

# %% [raw]
# dataframe.dtypes
# dataframe.ocorrencia_dia.dt.month

# %%
dataframe.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# Unnamed: 9                         float64
# Unnamed: 10                        float64
# dtype: object

# %% [raw]
# pip install pandera

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade ": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_lenght(2,2)),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int)
        
,        
        
    }
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-b92a4b2d4a0a> in <module>
#       5         "ocorrencia_classificacao": pa.Column(pa.String),
#       6         "ocorrencia_cidade ": pa.Column(pa.String),
# ----> 7         "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_lenght(2,2)),
#       8         "ocorrencia_aerodromo": pa.Column(pa.String),
#       9         "ocorrencia_dia": pa.Column(pa.DateTime),
#
# ~\anaconda3\lib\site-packages\pandera\checks.py in __getattr__(cls, name)
#      76         attr = ChainMap(cls.__dict__, cls.REGISTERED_CUSTOM_CHECKS).get(name)
#      77         if attr is None:
# ---> 78             raise AttributeError(
#      79                 f"'{cls}' object has no attribute '{name}'. "
#      80                 "Make sure any custom checks have been registered "
#
# AttributeError: '<class 'pandera.checks.Check'>' object has no attribute 'str_lenght'. Make sure any custom checks have been registered using the extensions api.

# %%
schema.validate(dataframe)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-03-01
# 1                  BEL�M            PA                 SBBE     2010-03-01
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-04-01
# 4                PELOTAS            RS                 SBPK     2010-05-01
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     2020-12-29
# 5748   LAGOA DA CONFUS�O            TO                 ****     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 ****     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes  Unnamed: 9  Unnamed: 10
# 0           12:00:00                    0         NaN          NaN
# 1           11:05:00                    0         NaN          NaN
# 2           03:00:00                    0         NaN          NaN
# 3           17:30:00                    0         NaN          NaN
# 4           19:25:00                    0         NaN          NaN
# ...              ...                  ...         ...          ...
# 5747        19:00:00                    0         NaN          NaN
# 5748        18:30:00                    0         NaN          NaN
# 5749        00:54:00                    0         NaN          NaN
# 5750        09:00:00                    0         NaN          NaN
# 5751        13:24:00                    0         NaN          NaN
#
# [5752 rows x 11 columns]

# %%
schema.validate(dataframe)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-03-01
# 1                  BEL�M            PA                 SBBE     2010-03-01
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-04-01
# 4                PELOTAS            RS                 SBPK     2010-05-01
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     2020-12-29
# 5748   LAGOA DA CONFUS�O            TO                 ****     2020-12-30
# 5749      RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5750           VICENTINA            MS                 ****     2020-12-31
# 5751      RIO DE JANEIRO            RJ                 SBJR     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes  Unnamed: 9  Unnamed: 10
# 0           12:00:00                    0         NaN          NaN
# 1           11:05:00                    0         NaN          NaN
# 2           03:00:00                    0         NaN          NaN
# 3           17:30:00                    0         NaN          NaN
# 4           19:25:00                    0         NaN          NaN
# ...              ...                  ...         ...          ...
# 5747        19:00:00                    0         NaN          NaN
# 5748        18:30:00                    0         NaN          NaN
# 5749        00:54:00                    0         NaN          NaN
# 5750        09:00:00                    0         NaN          NaN
# 5751        13:24:00                    0         NaN          NaN
#
# [5752 rows x 11 columns]
