# %%
nome = input()
# Out:
# Eva

# %%
nome
# Out:
# 'Eva'

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print("Olá, Júnior!")
print("Sua idade é 29 anos")
print("Seu peso é 80 kg.")
# Out:
# Olá, Júnior!
# Sua idade é 29 anos
# Seu peso é 80 kg.

# %%
nome = "Oswaldo"
idade = "25."
peso = "75.8"
print("Olá, "+nome+" !")
print("Sua idade é"+idade+" anos.")
print("Seu peso é "+peso+" kg.")
# Out:
# Olá, Oswaldo !
# Sua idade é25. anos.
# Seu peso é 75.8 kg.

# %%
print(f"Olá, {nome} !")
print(f"Sua idade é {idade} anos. ")
print(f"Seu peso é {peso} kg.")
# Out:
# Olá, Oswaldo !
# Sua idade é 25. anos.
# Seu peso é 75.8 kg.

# %%
nome = "Roberto" #string
idade = 21 #int
altura = 1.75 #float
print(nome)
print(idade)
print(altura)
# Out:
# Roberto
# 21
# 1.75

# %%
type(nome)
# Out:
# str

# %%
type(idade)
# Out:
# int

# %%
type(altura)
# Out:
# float

# %%
nome = input()
# Out:
# Eva

# %%
nome
# Out:
# 'Eva'

# %%
x = 10
x = 10.5
print(x) #O último valor é considerado
# Out:
# 10.5

# %%
nome = input("Digite seu nome: ")
idade = input("Digite sua idade: ")
peso = input("Digite seu peso: ")
# Out:
# Digite seu nome: Ana
# Digite sua idade: 20
# Digite seu peso: 65

# %%
nome
# Out:
# 'Ana'

# %%
idade
# Out:
# '20'

# %%
peso
# Out:
# '65'

# %%
type(nome)
# Out:
# str

# %%
type(idade)
# Out:
# str

# %%
type(peso)
# Out:
# str

# %%
idade+idade #concatenou as idades dividir não daria certo
# Out:
# '2020'

# %%
print(f"Nome: {nome}")  
print(f"Idade: {idade}") 
print(f"Peso: {peso}")
# Out:
# Nome: Ana
# Idade: 20
# Peso: 65

# %%
x = 10
y = 20
z = 70

# %%
print(x,y,z)
# Out:
# 10 20 70

# %%
x,y,z = 25,30,40

# %%
print(x,y,z)
# Out:
# 25 30 40

# %%
x = 10
y = 15
z = 20
w = 30

# %%
x, y , z, w = 10,15,20, 30

# %%
x = y = 0

# %%
print(x,y)
# Out:
# 0 0

# %%
x = y = z = 10

# %%
print(x,y,z)
# Out:
# 10 10 10

# %%
x = 10 #int
y = 10.5 #float
z = 10+1j #complex
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
#conversão

# %%
idade = int(input("Digite sua idade: "))
type(idade)
# Out:
# Digite sua idade: 18
# int

# %%
peso = float(input("Digite seu peso: "))
# Out:
# Digite seu peso: 80

# %%
type(peso)
# Out:
# float

# %%
numero = "10"
print(type(int(numero)))
# Out:
# <class 'int'>

# %%
int("10")
# Out:
# 10

# %%
int(10.5)
# Out:
# 10

# %%
numero = float(100)
print(type(numero))
# Out:
# <class 'float'>

# %%
int("10")
# Out:
# 10

# %%
#calculadora

# %%
10.5+10
# Out:
# 20.5

# %%
print(17.2-5)
# Out:
# 12.2

# %%
print(10/5)
# Out:
# 2.0

# %%
print(10/3)
# Out:
# 3.3333333333333335

# %%
print(8%2) #pegar o resto da divisão(Se é par ou impar)
# Out:
# 0

# %%
print(10//3) #pegar somente o valor inteiro
# Out:
# 3

# %%
print(9%2)
# Out:
# 1

# %%
print(2**2) #elevar ao quadrado
# Out:
# 4

# %%
print(50*10)
# Out:
# 500

# %%
4**0.5 #tirar a raiz quadrada tbm poderia ser aceito 1/2
# Out:
# 2.0

# %%
nome = "UserPython"

# %%
nome[0]
# Out:
# 'U'

# %%
nome[:2] #exibir duas letras
# Out:
# 'Us'

# %%
len(nome) #contar a quantidade de letras
# Out:
# 10

# %%
nome[4]
# Out:
# 'P'

# %%
nome[1]
# Out:
# 's'

# %%
nome[0:3]
# Out:
# 'Use'

# %%
nome[0:4]
# Out:
# 'User'

# %%
nome[4:]
# Out:
# 'Python'

# %%
nome[:4]
# Out:
# 'User'

# %%
nome[:2
    ]
# Out:
# 'Us'

# %%
nome[:]
# Out:
# 'UserPython'

# %%
len(nome) #exibe a quantidade de caracteres
# Out:
# 10

# %%
len("Python")
# Out:
# 6

# %%
len("Usdr")
# Out:
# 4

# %%
len("User")
# Out:
# 4

# %%
len(nome)
# Out:
# 10

# %%
a = "Python World"
"Python" in a
# Out:
# True

# %%
f = "Python World"
"Ruby" in f
# Out:
# False

# %%
nome not in "UserPython UserPython"
# Out:
# False

# %%
nome = "João"

# %%
nome.lower()
# Out:
# 'joão'

# %%
nome.upper()
# Out:
# 'JOÃO'

# %%
nome in "UserPython UserPython"
# Out:
# False

# %%
ling = " Python " #remover espaços 
ling.strip()
# Out:
# 'Python'

# %%
nome = " joão carlos da silva "
nome.title()
# Out:
# ' João Carlos Da Silva '

# %%
linguagem = input("Digite sua linguagem de programação: ")
# Out:
# Digite sua linguagem de programação: Python

# %%
linguagem
# Out:
# 'Python'

# %%
nome = " joão carlos da silva     "
nome.title()
# Out:
# ' João Carlos Da Silva     '

# %%
nome.strip().title()
# Out:
# 'João Carlos Da Silva'

# %%
nome.index('j')
# Out:
# 1

# %%
#Operadores

# %%
10 == 10
# Out:
# True

# %%
10 != 10
# Out:
# False

# %%
10 != 2
# Out:
# True

# %%
10 >= 10
# Out:
# True

# %%
10 > 10
# Out:
# False

# %%
10 <= 10
# Out:
# True

# %%
10 < 10
# Out:
# False

# %%
string1 = "Python"
string2 = "Java"
resultado = len(string1)>len(string2)
print(resultado)
# Out:
# True

# %%
#Operadores lógicos

# %%
x = 10

# %%
(x<20) and (x>2) #retorna True se ambas as declaraçoes forem verdadeiras
# Out:
# True

# %%
(x>20) and (x>2)
# Out:
# False

# %%
(x!=10) or (x>2)#Ou um ou outro verdadeiro
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and Truee
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
False or False or True
# Out:
# True

# %%
True and True and True
# Out:
# True

# %%
True and True and False
# Out:
# False

# %%
#listas

# %%
lista1 = [10,20,30,40]

# %%
lista2 = ['Hello World!', 10,20,30, [1,2,3], (45, 50)]

# %%
type(lista1)
# Out:
# list

# %%
type(lista2)
# Out:
# list

# %%
lista = ['A', 'B', 'C'] #Acessando elementos da lista via indice

# %%
#A lista é mutável a tupla não

# %%
lista[0]
# Out:
# 'A'

# %%
#modificar
lista[0] = 'Z'

# %%
lista
# Out:
# ['Z', 'B', 'C']

# %%
#forma de indexação do elemento final para o primeiro

# %%
b = ['a', 'c', 'd','h']

# %%
b[-1]
# Out:
# 'h'

# %%
b[-2]
# Out:
# 'd'

# %%
b[0]
# Out:
# 'a'

# %%
b[-4]
# Out:
# 'a'

# %%
#Máximo, minimo,soma e tamanho de uma lista

# %%
num =[31, 914,236, 376, 140, 705]

# %%
max(num)
# Out:
# 914

# %%
min(num)
# Out:
# 31

# %%
len(num) #tamanho do array
# Out:
# 6

# %%
sum(num)
# Out:
# 2402

# %%
#média = soma de array / tamanho dele
media = sum(num)/len(num)

# %%
media
# Out:
# 400.3333333333333

# %%
print(f'Valor máximo: {max(num)}')
print(f'Valor mínimo: {min(num)}')
print(f'Números de elementos: {len(num)}')
print(f'Soma dos elementos: {sum(num)}')
# Out:
# Valor máximo: 914
# Valor mínimo: 31
# Números de elementos: 6
# Soma dos elementos: 2402

# %%
#Unir listas, concatenar

# %%
lista1 = ['a', 'b' 'c']
lista2 = ['d', 'e', 'f', 'g']
lista3 = ['h', 'i', 'j', 'k']
uniao = lista1+lista2+lista3
print(uniao)
# Out:
# ['a', 'bc', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']

# %%
#Repetir elementos da lista

# %%
j = [0,1,2]
j*7
# Out:
# [0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2]

# %%
string = "Python"
string*4
# Out:
# 'PythonPythonPythonPython'
